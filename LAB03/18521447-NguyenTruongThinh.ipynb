# %% [markdown]
# # CS105.L22.KHCL - 18521447 - Nguyễn Trường Thịnh

# %% [markdown]
# # Import packages

# %%
import cv2
import time
import matplotlib as mpl
import matplotlib.pyplot as plt

# %% [markdown]
# # Config notebooks

# %%
mpl.rcParams["figure.dpi"]=100

# %%
# !ls
# Out:
# 18521447-NguyenTruongThinh.ipynb  haarcascade_frontalface_default.xml
# cars.avi			  haarcascade_mmm.xml
# cars.xml			  pedestrian.xml
# crowd.jpg			  walking.avi

# %% [markdown]
# # Câu 1

# %%
face_cascade = cv2.CascadeClassifier("haarcascade_frontalface_default.xml")

# %%
img = cv2.imread("crowd.jpg")
rgb = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)

faces = face_cascade.detectMultiScale(gray, 1.1, 4)

for (x, y, w, h) in faces:
    cv2.rectangle(rgb, (x, y), (x+w, y+h), (83, 250, 154), 30)
plt.imshow(rgb)

# %% [markdown]
# ## Câu 1.1

# %%
mmm_cascade = cv2.CascadeClassifier("haarcascade_mmm.xml")

# %%
img = cv2.imread("crowd.jpg")
rgb = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)

mmms = mmm_cascade.detectMultiScale(gray, 1.1, 4)

for (x, y, w, h) in mmms:
    cv2.rectangle(rgb, (x, y), (x+w, y+h), (83, 250, 154), 30)
plt.imshow(rgb)

# %% [markdown]
# # Câu 2

# %%
car_cascade = cv2.CascadeClassifier("cars.xml")

# %%
cap = cv2.VideoCapture("cars.avi")

while cap.isOpened():
    ret, frame = cap.read()
    
    if not ret:
        break
        
    gray = cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY)

    cars = car_cascade.detectMultiScale(gray, 1.4, 2)

    for (x, y, w, h) in cars:
        cv2.rectangle(frame, (x, y), (x+w, y+h), (83, 250, 154), 2)
    cv2.imshow("Video", frame)
    
    # Press "Enter" to exit
    if cv2.waitKey(1) == 13:
            break
cap.release()
cv2.destroyAllWindows()

# %% [markdown]
# # Câu 3

# %%
pedestrian_cascade = cv2.CascadeClassifier("pedestrian.xml")

# %%
cap = cv2.VideoCapture("walking.avi")

while cap.isOpened():
    ret, frame = cap.read()
    
    if not ret:
        break
        
    gray = cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY)

    pedestrians = pedestrian_cascade.detectMultiScale(gray, 1.4, 2)

    for (x, y, w, h) in pedestrians:
        cv2.rectangle(frame, (x, y), (x+w, y+h), (83, 250, 154), 2)
    cv2.imshow("Video", frame)
    
    # Press "Enter" to exit
    if cv2.waitKey(1) == 13:
            break
cap.release()
cv2.destroyAllWindows()
